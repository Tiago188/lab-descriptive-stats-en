# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import csv
import pandas as pd

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
# YOUR CODE HERE
df = pd.read_csv("Temp_States.csv")
temp = pd.DataFrame(df)

# %% [markdown]
# #### Print `temp`

# %%
# your solution here
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
# YOUR CODE HERE
temp.dtypes # city and State are Strings (categorical data) and temperature is float (numerical or quantitative data)
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %% [markdown]
# #### Select the rows where state is New York

# %%
# YOUR CODE HERE
ny_temp = temp[temp['State'] == 'New York']
ny_temp
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# YOUR CODE HEREA
ny_temperture = ny_temp['Temperature'].tolist() #convert in to a list
avg_ny_temp = sum(ny_temperture) / len(ny_temperture) if ny_temperture else 0
avg_ny_temp
# Out:
# 10.74074074074074

# %% [markdown]
# ## We want to know cities and states with Temperature above 15 degress Celcius

# %%
# your answer here
filter_15degress = temp[temp['Temperature'] > 15]
filter_15degress
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# YOUR CODE HERE
city_15degress = temp[temp['Temperature'] > 15]['City'].tolist()
city_15degress
# Out:
# ['NYC', 'Hartford', 'Treton', 'Newark']

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# YOUR CODE HERE

# %%
cities_above15_below20 = temp[(temp['Temperature'] > 15) & (temp['Temperature'] < 20)]['City'].tolist()
cities_above15_below20
# Out:
# ['NYC', 'Hartford']

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# YOUR CODE HERE
state_av_std = temp.groupby('State')['Temperature'].agg(['mean', 'std'])
round(state_av_std)
# Out:
#              mean  std
# State
# Connecticut  16.0  2.0
# New Jersey   21.0  2.0
# New York     11.0  8.0

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
# YOUR CODE HERE
df2 = pd.read_csv("employee.csv")
employee = pd.DataFrame(df2)

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# YOUR CODE HERE
employee.dtypes # all the columns are strings (categorical data) except Year and Salary that are integers (numerical or quantitative data)
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
# your answer here

# %%
# YOUR CODE HERE
import matplotlib.pyplot as plt

salary = employee['Salary']

# Create a histogram
plt.figure(figsize=(8, 5))  # Set the figure size
plt.hist(salary, bins=5, color='skyblue', edgecolor='black')  # Create the histogram

# Add labels and title
plt.title('Salary Distribution of Employees', fontsize=16)
plt.xlabel('Salary', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

# Show the plot
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Optional: Add a grid for better visualization
plt.show()

# %%
# YOUR CODE HERE

# %% [markdown]
# #### What's the average salary in this company?

# %%
# YOUR CODE HERE
round(salary.mean(),2)
# Out:
# 48.89

# %% [markdown]
# #### What's the highest salary?

# %%
# YOUR CODE HERE
salary.max()
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
# YOUR CODE HERE
salary.min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# YOUR CODE HERE
low_salary_emp = employee[employee['Salary'] == 30]
low_salary_emp
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# YOUR CODE HERE
david_emp = employee[employee['Name'] == 'David']
david_emp
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# YOUR CODE HERE
david_salary = david_emp['Salary'].values[0]
print(f"David Salary is :{david_salary}")
# Out:
# David Salary is :30

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
# YOUR CODE HERE
associates = employee[employee['Title'] == "associate"]
associates
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# YOUR CODE HERE
employee[0:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# YOUR CODE HERE

# %%
employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# YOUR CODE HERE
associates_more_55 = employee[(employee['Title'] == "associate") & (employee['Salary'] > 55)]
associates_more_55
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
# YOUR CODE HERE
av_salaries = employee.groupby('Years')['Salary'].mean().reset_index()
round(av_salaries, 2)
# Out:
#    Years  Salary
# 0      1   35.00
# 1      2   38.33
# 2      3   55.00
# 3      4   35.00
# 4      7   60.00
# 5      8   70.00

# %% [markdown]
# ####  What is the average Salary per title?

# %%
# YOUR CODE HERE
av_title = employee.groupby('Title')['Salary'].mean().reset_index()
round(av_title, 2)
# Out:
#        Title  Salary
# 0         VP   70.00
# 1    analyst   32.50
# 2  associate   56.67

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
#
# * Hint : Quantiles vs Quartiles*
# In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.

# %%
# YOUR CODE HERE
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

av_title = employee.groupby('Title')['Salary'].mean().reset_index()
plt.figure(figsize=(8, 5))  # Set the figure size
sns.boxplot(x='Title', y='Salary', data=employee, palette='Set2')

# Add labels and title
plt.title('Boxplot of Salary by Job Title', fontsize=16)
plt.xlabel('Title', fontsize=12)
plt.ylabel('Salary', fontsize=12)

# Show the plot
plt.show()
# Out:
# C:\Users\ggsan\AppData\Local\Temp\ipykernel_7768\369915736.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Title', y='Salary', data=employee, palette='Set2')

# %%
# print first quartile here
first_quartile = employee['Salary'].quantile(0.25)
first_quartile
# Out:
# 35.0

# %%
# print third quartile here
third_quartile = employee['Salary'].quantile(0.75)
third_quartile
# Out:
# 60.0

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
# your answer here
av_gender_Salary = employee.groupby('Gender')['Salary'].mean().reset_index()
round(av_gender_Salary, 2)
# Out:
#   Gender  Salary
# 0      F    47.5
# 1      M    50.0

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
cat = employee.select_dtypes(exclude="number")
num = employee.select_dtypes(include="number")
cat
# Out:
#      Name Department Education Gender      Title
# 0    Jose         IT  Bachelor      M    analyst
# 1   Maria         IT    Master      F    analyst
# 2   David         HR    Master      M    analyst
# 3   Sonia         HR  Bachelor      F    analyst
# 4  Samuel      Sales    Master      M  associate
# 5     Eva      Sales  Bachelor      F  associate
# 6  Carlos         IT    Master      M         VP
# 7   Pedro         IT       Phd      M  associate
# 8     Ana         HR    Master      F         VP

# %%
# your answer here
department_stats = employee.groupby('Department').agg({
    'Salary': ['min', 'mean', 'max'],
    'Years': ['min', 'mean', 'max']
})

department_stats
# Out:
#            Salary            Years
#               min   mean max   min      mean max
# Department
# HR             30  45.00  70     2  4.666667   8
# IT             30  48.75  70     1  4.500000   8
# Sales          55  55.00  55     2  2.500000   3

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here
salary_diff = employee.groupby('Department')['Salary'].agg(lambda x: x.max() - x.min())
salary_diff
# Out:
# Department
# HR       40
# IT       40
# Sales     0
# Name: Salary, dtype: int64

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
# your answer here
df3 = pd.read_csv("Orders.csv")
orders = pd.DataFrame(df3)

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
# your answer here
orders.dtypes
# Out:
# Unnamed: 0        int64
# InvoiceNo         int64
# StockCode        object
# year              int64
# month             int64
# day               int64
# hour              int64
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# amount_spent    float64
# dtype: object

# %%
# your answer here
cat = orders.select_dtypes(exclude="number")
num = orders.select_dtypes(include="number")
cat
# Out:
#        StockCode                          Description          InvoiceDate  \
# 0         85123A   white hanging heart t-light holder  2010-12-01 08:26:00
# 1          71053                  white metal lantern  2010-12-01 08:26:00
# 2         84406B       cream cupid hearts coat hanger  2010-12-01 08:26:00
# 3         84029G  knitted union flag hot water bottle  2010-12-01 08:26:00
# 4         84029E       red woolly hottie white heart.  2010-12-01 08:26:00
# ...          ...                                  ...                  ...
# 397919     22613          pack of 20 spaceboy napkins  2011-12-09 12:50:00
# 397920     22899         children's apron dolly girl   2011-12-09 12:50:00
# 397921     23254        childrens cutlery dolly girl   2011-12-09 12:50:00
# 397922     23255      childrens cutlery circus parade  2011-12-09 12:50:00
# 397923     22138        baking set 9 piece retrospot   2011-12-09 12:50:00
#
#                Country
# 0       United Kingdom
# ...

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
# your answer here
orders['amount_spent'].mean()
# Out:
# 22.394748504739596

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
# your answer here
orders['amount_spent'].max()
# Out:
# 168469.6

# %%
# your answer here
orders['amount_spent'].min()
# Out:
# 0.0

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
# your answer here
spain_customers = orders[orders['Country'] == 'Spain']
spain_customers
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# ...            ...        ...       ...   ...    ...  ...   ...
# 394733      535271     581193     23291  2011     12    3    17
# 394734      535272     581193    85232D  2011     12    3    17
# 394735      535273     581193     22721  2011     12    3    17
# 394736      535274     581193     23241  2011     12    3    17
# 394737      535275     581193     23247  2011     12    3    17
#
#                           Description  Quantity          InvoiceDate  \
# 4250          lunch bag suki  design         70  2010-12-03 12:20:00
# ...

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
# your answer here
count_spain_customers = len(spain_customers)
count_spain_customers
# Out:
# 2485

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
# your answer here
Customers_M_50items = orders[orders['Quantity'] > 50]
Customers_M_50items
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 46              46     536371     22086  2010     12    3     9
# 83              83     536376     21733  2010     12    3     9
# 96              96     536378     21212  2010     12    3     9
# 102            102     536378    85071B  2010     12    3     9
# 174            176     536386    85099C  2010     12    3     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 397720      541702     581566     23404  2011     12    5    11
# 397721      541703     581567     21417  2011     12    5    11
# 397729      541711     581567     21326  2011     12    5    11
# 397761      541746     581571     23167  2011     12    5    12
# 397882      541867     581584     20832  2011     12    5    12
#
#                                Description  Quantity          InvoiceDate  \
# 46         paper chain kit 50's christmas         80  2010-12-01 09:00:00
# ...

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
# your answer here
Spain_Cust_M_50items = spain_customers[spain_customers['Quantity'] > 50]
Spain_Cust_M_50items
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# 32454        52416     540785    84997B  2011      1    2    11
# 32455        52417     540785    84997D  2011      1    2    11
# 32456        52418     540785    84997C  2011      1    2    11
# 32457        52419     540785    84997A  2011      1    2    11
# 91155       136767     547972     22383  2011      3    1    16
# 91156       136768     547972     22384  2011      3    1    16
# 91159       136771     547972     20728  2011      3    1    16
# 174442      248797     558871     22384  2011      7    1    13
# 174443      248798     558871     20727  2011      7    1    13
# ...

# %% [markdown]
# #### Select all free orders

# %%
# your answer here
Cust_free_Ord = orders[orders['amount_spent'] == 0]
Cust_free_Ord
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
# your answer here
Ord_lunch_bag = orders[orders['Description'].str.startswith("lunch bag")]
Ord_lunch_bag
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93              93     536378     20725  2010     12    3     9
# 172            174     536385     22662  2010     12    3     9
# 354            363     536401     22662  2010     12    3    11
# 359            368     536401     20725  2010     12    3    11
# 360            369     536401     22382  2010     12    3    11
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot        10  2010-12-01 09:37:00       1.65
# ...

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here
Ord2_lunch_bag = orders[orders['Description'].str.startswith("lunch bag")] & (orders['year'] == 2011)
Ord2_lunch_bag

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# spain_customers
freq_spain_customers = spain_customers['amount_spent'].value_counts().sort_index()
print(freq_spain_customers)
# Out:
# amount_spent
# 0.00       1
# 0.21       3
# 0.29       1
# 0.39       3
# 0.42       1
#           ..
# 417.50     1
# 488.16     2
# 1080.00    1
# 1220.40    2
# 1350.00    3
# Name: count, Length: 316, dtype: int64

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here
aug_orders = orders[orders['month'] == 8]
aug_orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 226483      320688     565067     22644  2011      8    3    17
# 226484      320689     565067     22645  2011      8    3    17
# 226485      320690     565067     22637  2011      8    3    17
# 226486      320691     565067     22646  2011      8    3    17
# 226487      320692     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 199475         6 ribbons elegant christmas         96  2011-08-01 08:30:00
# ...

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here
Orders_by_c_aug = aug_orders.groupby('Country')['amount_spent']. sum()
Orders_by_c_aug
# Out:
# Country
# Australia           22489.20
# Austria              1516.08
# Belgium              3554.02
# Canada                 51.56
# Channel Islands      4896.78
# Denmark               213.15
# EIRE                16967.38
# Finland              1376.50
# France              13810.96
# Germany             19220.77
# Iceland               584.91
# Israel               4873.81
# Italy                1990.95
# Malta                1119.00
# Netherlands         40327.81
# Norway               2025.81
# Poland                401.80
# Portugal             1221.40
# Spain                3346.91
# Sweden               1400.86
# Switzerland          4969.89
# United Kingdom     498453.32
# Unspecified           531.03
# Name: amount_spent, dtype: float64

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here
revenue_by_country = orders.groupby('Country')['amount_spent']. mean()
revenue_by_country
# Out:
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# Poland                   22.226212
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your answer here
most_exp_item = orders[orders['UnitPrice'] == orders['UnitPrice'].max()]
most_exp_item
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour Description  \
# 118352      173382     551697      POST  2011      5    2    13     postage
#
#         Quantity          InvoiceDate  UnitPrice  CustomerID         Country  \
# 118352         1  2011-05-03 13:46:00    8142.75       16029  United Kingdom
#
#         amount_spent
# 118352       8142.75

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here
revenue_by_year = orders.groupby('year')['amount_spent'].mean()
revenue_by_year
# Out:
# year
# 2010    21.892733
# 2011    22.430074
# Name: amount_spent, dtype: float64
